# %% [markdown]
# <a href="https://colab.research.google.com/github/neelkhairkar/python-programming/blob/main/exp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionary
a={23:"om", 24:"akshaf", 25:"Neel", 26:"pranali", "CT":"D D Nale"}
print(a)

#Checking Datatype
print(type(a))

#checking legth of Dict
print(len(a))

#Accessing keys
print(a.keys())

#Accessing values
print(a.values())

#Accessing the value from key
print(a['CT'])

#converting dict in to List or tuple
print(tuple(a))
